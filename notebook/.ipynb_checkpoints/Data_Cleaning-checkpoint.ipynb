# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
comments = pd.read_csv('../dataset/Comments.csv')

# %%
comments.head()
# Out:
#           id  course_id  rate                       date   display_name  \
# 0   88962892    3173036   1.0  2021-06-29T18:54:25-07:00          Rahul
# 1  125535470    4913148   5.0  2022-10-07T11:17:41-07:00          Marlo
# 2   68767147    3178386   3.5  2020-10-19T06:35:37-07:00  Yamila Andrea
# 3  125029758    3175814   5.0  2022-09-30T21:13:49-07:00     Jacqueline
# 4   76584052    3174896   4.5  2021-01-30T08:45:11-08:00        Anthony
#
#                                              comment
# 0  I think a beginner needs more than you think.\...
# 1  Aviva is such a natural teacher and healer/hea...
# 2  Muy buena la introducción para entender la bas...
# 3  This course is the best on Udemy.  This breakd...
# 4  I found this course very helpful. It was full ...

# %%
course = pd.read_csv('../dataset/Course_info.csv')

# %%
# Change the type of the data for efficient storage
dtypes = {'id' : 'int64',
          'num_subscribers' : 'int32',
          'num_reviews' : 'int32',
          'num_comments' : 'int32',
          'num_lectures' : 'int32',
          'content_length_min' : 'int32'}

course = course.astype(dtypes)

course['published_time'] = pd.to_datetime(course['published_time'])

course = course.rename(columns= {'id' : 'course_id'})

# %%
# inner join the comments and course info based on course_id
courses_data = comments.merge(course, on='course_id')

# %%
courses_data = courses_data[~(courses_data['content_length_min'] == 0)]

# %%
# filter the data courses only for english and indonesian language only
courses_data = courses_data[(courses_data['language'] == 'English') | (courses_data['language'] == 'Indonesian')]

# %%
def missing_value(df):
    
    missing = []
    for columns in df.columns:
        
        missing_shape = df[df[columns].isna()].shape
        percentage = round(missing_shape[0]/df.shape[0] * 100, 3)
        
        if df[columns].dtypes != 'object':
            max, min = df[columns].max(), df[columns].min()
        else:
            max, min = '-', '-'
            
        missing.append({'Columns' : columns,
                        'N/A count' : missing_shape[0],
                        'Percentage' : str(percentage) + '%',
                        'Max' : max,
                        'Min' : min}
                        )
    return pd.DataFrame(missing).sort_values(by='Percentage', ascending=False)

missing = missing_value(courses_data)
missing
# Out:
#                Columns  N/A count Percentage                        Max  \
# 4         display_name      72564     1.078%                          -
# 17    last_update_date       6800     0.101%                          -
# 5              comment       6365     0.095%                          -
# 24      instructor_url       6205     0.092%                          -
# 20               topic       5871     0.087%                          -
# 9             headline        853     0.013%                          -
# 23     instructor_name         60     0.001%                          -
# 14        num_lectures          0       0.0%                       1095
# 22          course_url          0       0.0%                          -
# 21            language          0       0.0%                          -
# 19         subcategory          0       0.0%                          -
# 18            category          0       0.0%                          -
# 16      published_time          0       0.0%  2022-10-05 16:07:16+00:00
# 15  content_length_min          0       0.0%                      22570
# 0                   id          0       0.0%                  126709072
# 13        num_comments          0       0.0%                      39040
# 1            course_id          0       0.0%                    4913148
# 11          avg_rating          0       0.0%                        5.0
# 10     num_subscribers          0       0.0%                    1752364
# 8                price          0       0.0%                      999.0
# 7              is_paid          0       0.0%                       True
# 6                title          0       0.0%                          -
# 3                 date          0       0.0%                          -
# 2                 rate          0       0.0%                        5.0
# 12         num_reviews          0       0.0%                     436457
#
#                           Min
# 4                           -
# 17                          -
# 5                           -
# 24                          -
# 20                          -
# 9                           -
# 23                          -
# 14                          1
# 22                          -
# 21                          -
# 19                          -
# 18                          -
# 16  2010-01-12 18:09:46+00:00
# 15                          2
# 0                          54
# 13                          1
# 1                        1769
# 11                        0.0
# 10                          0
# 8                         0.0
# 7                       False
# 6                           -
# 3                           -
# 2                         0.5
# 12                          1

# %%
# Total missing value
missing_percentage = missing['N/A count'].sum() / courses_data.shape[0] * 100
print('Missing Value Percentage = {:.2f}%'.format(missing_percentage))
# Out:
# Missing Value Percentage = 1.47%

# %%
# we can safely drop the missing value since the percentage is below 5% 
courses_data.dropna(inplace=True)

# %%
# Check duplicated value
duplicated_sum = courses_data.duplicated().sum()
duplicated_percentage = duplicated_sum / courses_data.shape[0] * 100

# Print total duplicated value and its percentage
print('Total Duplicate Data = {} \nDuplicated Percentage = {:.2f}%'.format(duplicated_sum, duplicated_percentage))
# Out:
# Total Duplicate Data = 0
# Duplicated Percentage = 0.00%

# %%
# get sample data; take 5%
sample_data = courses_data.sample(frac=0.05)

# %%
plt.figure(figsize=(10,5))
ax = sns.histplot(sample_data, x='rate', bins=50)
ax.set(xlabel='Average Rating', title='Distribution of Average Rating per Course')
plt.margins(0.01)
plt.show()

# %%
sample_data.head()
# Out:
#                 id  course_id  rate                       date  display_name  \
# 9297182    9388140     625204   5.0  2017-09-08T02:15:37-07:00  John Douglas
# 6658616  125232566     821278   4.0  2022-10-04T01:40:55-07:00         Tanya
# 9410703   57899017     567828   5.0  2020-06-09T05:51:08-07:00         Rohan
# 8242594   43107550    1352468   4.0  2020-01-06T06:01:41-08:00      Abhishek
# 4070657   23581421    1915496   5.0  2018-11-25T19:35:03-08:00       Bryan T
#
#                                                    comment  \
# 9297182  examples are well thought through, the lessons...
# 6658616  Helps in increasing knowledge and run through ...
# 9410703  Yes. I don't feel overwhelmed about learning h...
# 8242594  Overall course was good except last two lectur...
# 4070657  I love the speech delivery speed and articulat...
#
#                                                      title  is_paid   price  \
# 9297182                    The Web Developer Bootcamp 2022     True  199.99
# 6658616  INTERVIEW TRAINING: Ask Better Questions, Hire...     True   19.99
# 9410703  2022 Complete Python Bootcamp From Zero to Her...     True  199.99
# 8242594  Master Microservices with Spring Boot and Spri...     True  199.99
# 4070657  Facebook Marketing -  Build Facebook Messenger...     True  199.99
#
#                                                   headline  ...  \
# 9297182  COMPLETELY REDONE - The only course you need t...  ...
# 6658616  If you want to improve your hiring accuracy or...  ...
# 9410703  Learn Python like a Professional  Start from t...  ...
# 8242594  Java Spring Boot Microservices 5-in-1 - Spring...  ...
# 4070657  Facebook marketing & Facebook ads: Design, dev...  ...
#
#          content_length_min            published_time  last_update_date  \
# 9297182                3827 2015-11-02 21:13:27+00:00        2022-07-01
# 6658616                  99 2016-04-21 15:00:43+00:00        2017-01-31
# 9410703                1333 2015-10-12 21:42:53+00:00        2021-03-14
# 8242594                1318 2017-09-18 23:32:14+00:00        2022-10-03
# 4070657                 684 2018-09-18 18:14:25+00:00        2019-06-05
#
#             category            subcategory                topic language  \
# 9297182  Development        Web Development      Web Development  English
# 6658616     Business             Management  Interviewing Skills  English
# 9410703  Development  Programming Languages               Python  English
# 8242594  Development        Web Development        Microservices  English
# 4070657    Marketing      Digital Marketing   Facebook Marketing  English
#
#                                                 course_url  \
# 9297182                /course/the-web-developer-bootcamp/
# 6658616             /course/advanced-interviewer-training/
# 9410703                  /course/complete-python-bootcamp/
# 8242594  /course/microservices-with-spring-boot-and-spr...
# 4070657  /course/facebook-messenger-chatbot-marketing-t...
#
#               instructor_name         instructor_url
# 9297182           Colt Steele      /user/coltsteele/
# 6658616          James Colino    /user/james-colino/
# 9410703         Jose Portilla    /user/joseportilla/
# 8242594  in28Minutes Official     /user/in28minutes/
# 4070657        Isaac Rudansky  /user/isaac-rudansky/
#
# [5 rows x 25 columns]

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331855 entries, 9297182 to 354342
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  331855 non-null  int64
#  1   course_id           331855 non-null  int64
#  2   rate                331855 non-null  float64
#  3   date                331855 non-null  object
#  4   display_name        331855 non-null  object
#  5   comment             331855 non-null  object
#  6   title               331855 non-null  object
#  7   is_paid             331855 non-null  bool
#  8   price               331855 non-null  float64
#  9   headline            331855 non-null  object
#  10  num_subscribers     331855 non-null  int32
#  11  avg_rating          331855 non-null  float64
#  12  num_reviews         331855 non-null  int32
#  13  num_comments        331855 non-null  int32
#  14  num_lectures        331855 non-null  int32
#  15  content_length_min  331855 non-null  int32
#  16  published_time      331855 non-null  datetime64[ns, UTC]
#  17  last_update_date    331855 non-null  object
#  18  category            331855 non-null  object
#  19  subcategory         331855 non-null  object
#  20  topic               331855 non-null  object
#  21  language            331855 non-null  object
#  22  course_url          331855 non-null  object
#  23  instructor_name     331855 non-null  object
#  24  instructor_url      331855 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(3), int32(5), int64(2), object(13)
# memory usage: 57.3+ MB

# %%
# merge with another dataframe to get the image

image_df = pd.read_csv('../dataset/courses.csv')
image_df.head()
# Out:
#         id                                              title  \
# 0   567828  The Complete Python Bootcamp From Zero to Hero...
# 1  1565838         The Complete 2023 Web Development Bootcamp
# 2   625204                    The Web Developer Bootcamp 2023
# 3   756150        Angular - The Complete Guide (2023 Edition)
# 4  2776760  100 Days of Code: The Complete Python Pro Boot...
#
#                                               url    rating  num_reviews  \
# 0               /course/complete-python-bootcamp/  4.592782       452973
# 1  /course/the-complete-web-development-bootcamp/  4.667258       263152
# 2             /course/the-web-developer-bootcamp/  4.696147       254711
# 3        /course/the-complete-guide-to-angular-2/  4.592692       180257
# 4                       /course/100-days-of-code/  4.695252       177568
#
#    num_published_lectures               created last_update_date  \
# 0                     155  2015-07-29T00:12:23Z       2021-03-14
# 1                     490  2018-02-22T12:02:33Z       2023-01-20
# 2                     616  2015-09-28T21:32:19Z       2023-02-12
# 3                     472  2016-02-08T17:02:55Z       2023-02-06
# 4                     676  2020-01-24T10:47:21Z       2022-11-30
#
#            duration  instructors_id  \
# 0    22 total hours         9685726
# 1  65.5 total hours        31334738
# 2    64 total hours         4466306
# 3  34.5 total hours        13952972
# 4    64 total hours        31334738
#
#                                                image
# 0  https://img-c.udemycdn.com/course/750x422/5678...
# 1  https://img-c.udemycdn.com/course/750x422/1565...
# 2  https://img-c.udemycdn.com/course/750x422/6252...
# 3  https://img-c.udemycdn.com/course/750x422/7561...
# 4  https://img-c.udemycdn.com/course/750x422/2776...

# %%
image_df = image_df.rename(columns={'id' : 'course_id'})

# %%
image_df = image_df[['course_id', 'image']]

# %%
# inner join the comments and course info based on course_id
udemy_data = sample_data.merge(image_df, on='course_id')

# %%
udemy_data.head()
# Out:
#           id  course_id  rate                       date  display_name  \
# 0    9388140     625204   5.0  2017-09-08T02:15:37-07:00  John Douglas
# 1  125232566     821278   4.0  2022-10-04T01:40:55-07:00         Tanya
# 2   57899017     567828   5.0  2020-06-09T05:51:08-07:00         Rohan
# 3   43107550    1352468   4.0  2020-01-06T06:01:41-08:00      Abhishek
# 4   23581421    1915496   5.0  2018-11-25T19:35:03-08:00       Bryan T
#
#                                              comment  \
# 0  examples are well thought through, the lessons...
# 1  Helps in increasing knowledge and run through ...
# 2  Yes. I don't feel overwhelmed about learning h...
# 3  Overall course was good except last two lectur...
# 4  I love the speech delivery speed and articulat...
#
#                                                title  is_paid   price  \
# 0                    The Web Developer Bootcamp 2022     True  199.99
# 1  INTERVIEW TRAINING: Ask Better Questions, Hire...     True   19.99
# 2  2022 Complete Python Bootcamp From Zero to Her...     True  199.99
# 3  Master Microservices with Spring Boot and Spri...     True  199.99
# 4  Facebook Marketing -  Build Facebook Messenger...     True  199.99
#
#                                             headline  ...  \
# 0  COMPLETELY REDONE - The only course you need t...  ...
# 1  If you want to improve your hiring accuracy or...  ...
# 2  Learn Python like a Professional  Start from t...  ...
# 3  Java Spring Boot Microservices 5-in-1 - Spring...  ...
# 4  Facebook marketing & Facebook ads: Design, dev...  ...
#
#              published_time  last_update_date     category  \
# 0 2015-11-02 21:13:27+00:00        2022-07-01  Development
# 1 2016-04-21 15:00:43+00:00        2017-01-31     Business
# 2 2015-10-12 21:42:53+00:00        2021-03-14  Development
# 3 2017-09-18 23:32:14+00:00        2022-10-03  Development
# 4 2018-09-18 18:14:25+00:00        2019-06-05    Marketing
#
#              subcategory                topic  language  \
# 0        Web Development      Web Development   English
# 1             Management  Interviewing Skills   English
# 2  Programming Languages               Python   English
# 3        Web Development        Microservices   English
# 4      Digital Marketing   Facebook Marketing   English
#
#                                           course_url       instructor_name  \
# 0                /course/the-web-developer-bootcamp/           Colt Steele
# 1             /course/advanced-interviewer-training/          James Colino
# 2                  /course/complete-python-bootcamp/         Jose Portilla
# 3  /course/microservices-with-spring-boot-and-spr...  in28Minutes Official
# 4  /course/facebook-messenger-chatbot-marketing-t...        Isaac Rudansky
#
#           instructor_url                                              image
# 0      /user/coltsteele/  https://img-c.udemycdn.com/course/750x422/6252...
# 1    /user/james-colino/  https://img-b.udemycdn.com/course/750x422/8212...
# 2    /user/joseportilla/  https://img-c.udemycdn.com/course/750x422/5678...
# 3     /user/in28minutes/  https://img-c.udemycdn.com/course/750x422/1352...
# 4  /user/isaac-rudansky/  https://img-c.udemycdn.com/course/750x422/1915...
#
# [5 rows x 26 columns]

# %%
udemy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263591 entries, 0 to 263590
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  263591 non-null  int64
#  1   course_id           263591 non-null  int64
#  2   rate                263591 non-null  float64
#  3   date                263591 non-null  object
#  4   display_name        263591 non-null  object
#  5   comment             263591 non-null  object
#  6   title               263591 non-null  object
#  7   is_paid             263591 non-null  bool
#  8   price               263591 non-null  float64
#  9   headline            263591 non-null  object
#  10  num_subscribers     263591 non-null  int32
#  11  avg_rating          263591 non-null  float64
#  12  num_reviews         263591 non-null  int32
#  13  num_comments        263591 non-null  int32
#  14  num_lectures        263591 non-null  int32
#  15  content_length_min  263591 non-null  int32
#  16  published_time      263591 non-null  datetime64[ns, UTC]
#  17  last_update_date    263591 non-null  object
#  18  category            263591 non-null  object
#  19  subcategory         263591 non-null  object
#  20  topic               263591 non-null  object
#  21  language            263591 non-null  object
#  22  course_url          263591 non-null  object
#  23  instructor_name     263591 non-null  object
#  24  instructor_url      263591 non-null  object
#  25  image               263591 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(3), int32(5), int64(2), object(14)
# memory usage: 45.5+ MB

# %%
# save the csv file for further develop the analysis
udemy_data.to_csv('../dataset/Udemy_Cleaned.csv', index=False)

# %%
udemy_data = pd.read_csv('../dataset/Udemy_Cleaned.csv')

# %%
# get sample data; take 5%
sample_30 = udemy_data.sample(frac=0.3)

# %%
sample_30.to_csv('../dataset/udemy_sample_30.csv', index=False)
